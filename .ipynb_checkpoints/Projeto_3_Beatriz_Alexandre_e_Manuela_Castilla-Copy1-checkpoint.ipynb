# %%
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
import matplotlib as mpl  
import seaborn as sns
import numpy as np
import itertools
from scipy import stats
from emoji import UNICODE_EMOJI
from scipy.stats import norm, probplot, t
import statsmodels.api as sm
from pandas.core import datetools
from sklearn.linear_model import SGDClassifier
from sklearn.model_selection import train_test_split
from sklearn import datasets
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.naive_bayes import MultinomialNB
from sklearn.pipeline import Pipeline

# %% [markdown]
# Hipóteses

# %% [markdown]
# \begin{equation*}
#    H_0:\mbox{Tem poucas meninas na engenharia por motivos externos} \rightarrow \mu_B=\mu_A \rightarrow \mu_B-\mu_A=0
# \end{equation*}
# \begin{equation*}
#    H_a:\mbox{Tem poucas meninas na engenharia por motivos internos} \rightarrow \mu_B\neq\mu_A \rightarrow \mu_B-\mu_A\neq0
# \end{equation*}

# %% [markdown]
# Motivos externos: Mercado de trabalho, Salário, Vontade de outros
#
# Motivos internos: Gosto por exatas/ curso

# %% [markdown]
# # 1a Análise: Faz ou não engenharia no Insper?

# %% [markdown]
# ### Ler Arquivos Excel e colocar em um DataFrame

# %% [markdown]
# ## PRIMEIRO SHEET : meninas na engenharia insper

# %% [markdown]
# Lendo arquivo Excel

# %%
eng_insper = pd.read_excel('PESQUISA.xlsx', sheet_name = 0)

# %% [markdown]
# Limpar o DataFrame e Renomear algumas colunas

# %%
eng_insper = eng_insper.rename(columns={"Qual seu nome completo?": "NOME", "Qual semestre?": "SEMESTRE", "Idade": "IDADE", "Qual engenharia?": "TIPO_ENG", "De onde você veio (cidade/estado)?": "ESTADO/CID", "Frequentou o Ensino Médio...":"TIPO_EM", "Qual o nome do seu colégio?": "NOME_EM", 'Insper foi sua 1a opcao?': 'Sua atual faculdade foi sua 1a opção?', 'Como descobriu o Insper?':'Como descobriu sua faculdade?', 'Por que Insper?': 'Por que escolheu sua faculdade?'})


semestre=[]

for k in eng_insper.SEMESTRE:
    if k == "2º Semestre":
        semestre.append(2)
    elif k == "3º Semestre":
        semestre.append(3)
    elif k == "4º Semstre":
        semestre.append(4)
    elif k =="5º Semestre":
        semestre.append(5)
    elif k =="6º semestre":
        semestre.append(6)
    elif k == "7º Semestre":
        semestre.append(7)
    else:
         semestre.append(8)
            
eng_insper.SEMESTRE = semestre


eng_insper['Se "Não", qual?'] = eng_insper['Se "Não", qual?'].fillna('Insper')

eng_insper['Se SIM na pergunta anterior,  quais familiares?'] = eng_insper['Se SIM na pergunta anterior,  quais familiares?'].fillna('Ninguém')

# %%
eng_insper['Fez Insper?']='Sim'

# %%
eng_insper_idx=eng_insper.set_index('NOME')

# %% [markdown]
# ## SEGUNDO SHEET: engenharia de outras faculdades

# %% [markdown]
# Lendo arquivo Excel

# %%
eng_geral = pd.read_excel('PESQUISA.xlsx', sheet_name = 1)

# %% [markdown]
# Limpar o DataFrame e Renomear algumas colunas

# %%
eng_geral = eng_geral.rename(columns={"Qual seu nome completo?": "NOME", "Qual semestre?": "SEMESTRE", "Idade": "IDADE", "Qual engenharia?": "TIPO_ENG", "De onde você veio (cidade/estado)?": "ESTADO/CID", "Frequentou o Ensino Médio...":"TIPO_EM", "Qual o nome do seu colégio?": "NOME_EM"})


eng_geral['Se SIM na pergunta anterior,  quais familiares?'] = eng_geral['Se SIM na pergunta anterior,  quais familiares?'].fillna('Ninguém')


eng_geral['Se "Não", qual?'] = eng_geral['Se "Não", qual?'].fillna('A atual')


semestre=[]

for k in eng_geral.SEMESTRE:
    if k == "2º Semestre":
        semestre.append(2)
    elif k == "3º Semestre":
        semestre.append(3)
    elif k == "4º Semstre":
        semestre.append(4)
    elif k =="5º Semestre":
        semestre.append(5)
    elif k =="6º semestre":
        semestre.append(6)
    elif k == "7º Semestre":
        semestre.append(7)
    else:
         semestre.append(8)
            
eng_geral.SEMESTRE = semestre

# %%
eng_geral = eng_geral.drop('Distância da faculdade de casa...', 1)

# %%
eng_geral['Fez Insper?']='Não'

# %%
eng_geral_idx=eng_geral.set_index('NOME')

# %% [markdown]
# ## Juntando os DataFrames

# %%
eng_geral.shape
# Out:
# (90, 20)

# %%
len(eng_insper_idx)
# Out:
# 30

# %%
len(eng_geral_idx)
# Out:
# 90

# %%
len(pd.concat([eng_insper_idx, eng_geral_idx]))
# Out:
# 120

# %%
eng = pd.concat([eng_insper_idx, eng_geral_idx])
eng
# Out:
#                                                            IDADE  SEMESTRE  \
# NOME
# Vitória de Almeida Oliveira                   Entre 19 a 21 anos         2
# manuela castilla                              Entre 16 a 18 anos         2
# Mariana Sophia Abrantes                       Entre 19 a 21 anos         2
# Maria Clara Luques                            Entre 19 a 21 anos         8
# Beatriz Alexandre                             Entre 16 a 18 anos         2
# Beatriz Mie                                   Entre 19 a 21 anos         2
# Roberta Thome                                 Entre 19 a 21 anos         2
# Rachel Maria                                  Entre 19 a 21 anos         8
# Luiza Rodrigues silveira                      Entre 19 a 21 anos         2
# Vitoria Helena de Mattos Camilo               Entre 19 a 21 anos         8
# Milena Maluli                                 Entre 19 a 21 anos         4
# Giulia Braga Passarelli                       Entre 19 a 21 anos         4
# Emanuelle Silva Moço                          Entre 19 a 21 anos         3
# Carla Kim Gaieski                             Entre 19 a 21 anos         4
# Giovana Cristina Rocha Lemes                  Entre 19 a 21 anos         4
# Maria Eduarda Peppes Bicalho                  Entre 19 a 21 anos         4
# Juliana Costa Pessoa                          Entre 19 a 21 anos         8
# Alessandra Blucher                            Entre 19 a 21 anos         4
# Isabela Frederico Ribeiro                     Entre 22 a 25 anos         8
# Lúcia Coelho Richardson                       Entre 19 a 21 anos         4
# Ana Beatriz Bertolucci Henriques              Entre 19 a 21 anos         4
# Daniela Bento                                 Entre 19 a 21 anos         8
# Isabella Rocha de Oliveira                    Entre 19 a 21 anos         8
# Bruna Mayumi Kimura                           Entre 19 a 21 anos         8
# Gabriela Iannini Caruso                       Entre 16 a 18 anos         2
# Larissa Miras Floriano                        Entre 19 a 21 anos         8
# Mayra Peter da Rocha Loures                   Entre 16 a 18 anos         2
# Giovanna Sardella Cabral                      Entre 16 a 18 anos         2
# Sabrina Machado Bezerra                       Entre 19 a 21 anos         4
# Elisa Malzoni                                 Entre 19 a 21 anos         8
# ...                                                          ...       ...
# Fernanda Parodi                               Entre 19 a 21 anos         8
# Lidia Guimarães Gusmão                        Entre 22 a 25 anos         8
# Mariane Martins                               Entre 19 a 21 anos         2
# Giulia Steck                                  Entre 16 a 18 anos         8
# Carla Irrazabal                               Entre 22 a 25 anos         8
# Gabriela Santos Silva                         Entre 19 a 21 anos         3
# Fernanda Ribeiro                              Entre 19 a 21 anos         5
# Vanessa Freitas de Souza                      Entre 19 a 21 anos         2
# Esteffany Menezes Ferreira                    Entre 22 a 25 anos         8
# Letícia Paraíso                               Entre 16 a 18 anos         8
# Carolina Gali Barroso                         Entre 16 a 18 anos         8
# Veronica G Souza                              Entre 19 a 21 anos         8
# Giovanna carvalho gazzillo                    Entre 19 a 21 anos         2
# Luisa Boccardo Burini                         Entre 22 a 25 anos         8
# Karen Cerveira Alves                          Entre 22 a 25 anos         8
# Lorenza De Maria Sotto Teixeira               Entre 19 a 21 anos         5
# Marina Cerqueira                              Entre 19 a 21 anos         8
# Daniela Souza de Oliveira                     Entre 22 a 25 anos         7
# Thalita Argila Soares                         Entre 22 a 25 anos         8
# Nathalya Aline dos Santos Rodrigues da Silva  Entre 19 a 21 anos         2
# Nathália de Paula Machado                     Entre 19 a 21 anos         8
# Laís Alves Saraiva                            Entre 19 a 21 anos         2
# Isabella Tolim                                Entre 19 a 21 anos         8
# Gustavo urenha toscano                        Entre 19 a 21 anos         8
# Gabriela Gonçalves                            Entre 19 a 21 anos         3
# Lorenza De Maria Sotto Teixeira               Entre 19 a 21 anos         5
# Sarah Fernandes de Souza                      Entre 16 a 18 anos         8
# Amanda Vaitiman Damaceno                      Entre 22 a 25 anos         8
# Mickaela Ester Barros Barrero                 Entre 19 a 21 anos         2
# Barbara Alves De Melo                         Entre 19 a 21 anos         3
#
#                                                               TIPO_ENG  \
# NOME
# Vitória de Almeida Oliveira                     Engenharia Mecatrônica
# manuela castilla                                Engenharia Mecatrônica
# Mariana Sophia Abrantes                            Engenharia Mecânica
# Maria Clara Luques                              Engenharia Mecatrônica
# Beatriz Alexandre                                  Engenharia Mecânica
# Beatriz Mie                                   Engenharia da Computação
# Roberta Thome                                   Engenharia Mecatrônica
# Rachel Maria                                       Engenharia Mecânica
# Luiza Rodrigues silveira                      Engenharia da Computação
# Vitoria Helena de Mattos Camilo               Engenharia da Computação
# Milena Maluli                                      Engenharia Mecânica
# Giulia Braga Passarelli                       Engenharia da Computação
# Emanuelle Silva Moço                          Engenharia da Computação
# Carla Kim Gaieski                               Engenharia Mecatrônica
# Giovana Cristina Rocha Lemes                    Engenharia Mecatrônica
# Maria Eduarda Peppes Bicalho                  Engenharia da Computação
# Juliana Costa Pessoa                               Engenharia Mecânica
# Alessandra Blucher                            Engenharia da Computação
# Isabela Frederico Ribeiro                          Engenharia Mecânica
# Lúcia Coelho Richardson                       Engenharia da Computação
# Ana Beatriz Bertolucci Henriques                Engenharia Mecatrônica
# Daniela Bento                                   Engenharia Mecatrônica
# Isabella Rocha de Oliveira                    Engenharia da Computação
# Bruna Mayumi Kimura                           Engenharia da Computação
# Gabriela Iannini Caruso                       Engenharia da Computação
# Larissa Miras Floriano                             Engenharia Mecânica
# Mayra Peter da Rocha Loures                     Engenharia Mecatrônica
# Giovanna Sardella Cabral                      Engenharia da Computação
# Sabrina Machado Bezerra                       Engenharia da Computação
# Elisa Malzoni                                 Engenharia da Computação
# ...                                                                ...
# Fernanda Parodi                                    Engenharia Elétrica
# Lidia Guimarães Gusmão                             Engenharia Elétrica
# Mariane Martins                                    Engenharia Elétrica
# Giulia Steck                                     Engenharia Computação
# Carla Irrazabal                                    Engenharia Elétrica
# Gabriela Santos Silva                            Engenharia Ambiental
# Fernanda Ribeiro                                   Não escolhi ainda.
# Vanessa Freitas de Souza                           Engenharia Elétrica
# Esteffany Menezes Ferreira                         Engenharia Elétrica
# Letícia Paraíso                                  Engenharia de Energia
# Carolina Gali Barroso                          Engenharia de Materiais
# Veronica G Souza                               Engenharia de Materiais
# Giovanna carvalho gazzillo                     Engenharia de Materiais
# Luisa Boccardo Burini                            Engenharia Computação
# Karen Cerveira Alves                               Engenharia Mecânica
# Lorenza De Maria Sotto Teixeira                       Engenharia Civil
# Marina Cerqueira                                   Engenharia Elétrica
# Daniela Souza de Oliveira                          Engenharia Elétrica
# Thalita Argila Soares                         Engenharia Aeroespacial
# Nathalya Aline dos Santos Rodrigues da Silva       Engenharia Elétrica
# Nathália de Paula Machado                         Engenharia Biomédica
# Laís Alves Saraiva                             Engenharia de materiais
# Isabella Tolim                                        Engenharia Civil
# Gustavo urenha toscano                                Engenharia Civil
# Gabriela Gonçalves                                    Engenharia Civil
# Lorenza De Maria Sotto Teixeira                       Engenharia Civil
# Sarah Fernandes de Souza                          Engenharia Biomédica
# Amanda Vaitiman Damaceno                           Engenharia Mecânica
# Mickaela Ester Barros Barrero                    Engenharia Ambiental
# Barbara Alves De Melo                            Engenharia de Gestão
#
#                                                             ESTADO/CID  \
# NOME
# Vitória de Almeida Oliveira                                  Osasco SP
# manuela castilla                                          São Paulo SP
# Mariana Sophia Abrantes                                   São Paulo SP
# Maria Clara Luques                                          Barueri SP
# Beatriz Alexandre                                         São Paulo SP
# Beatriz Mie                                   São Bernardo do Campo SP
# Roberta Thome                                             São Paulo SP
# Rachel Maria                                              São Paulo SP
# Luiza Rodrigues silveira                                 Uberlândia MG
# Vitoria Helena de Mattos Camilo                     Mogi das Cruzes SP
# Milena Maluli                                             São Paulo SP
# Giulia Braga Passarelli                                   São pAulo SP
# Emanuelle Silva Moço                                         Santos SP
# Carla Kim Gaieski                                         São Paulo SP
# Giovana Cristina Rocha Lemes                               Sorocaba SP
# Maria Eduarda Peppes Bicalho                               Salvador BA
# Juliana Costa Pessoa                                      São Paulo SP
# Alessandra Blucher                                        São Paulo SP
# Isabela Frederico Ribeiro                                  Campinas SP
# Lúcia Coelho Richardson                                Campo Grande MS
# Ana Beatriz Bertolucci Henriques                          Guarulhos SP
# Daniela Bento                                          Porto Alegre RS
# Isabella Rocha de Oliveira                                São Paulo SP
# Bruna Mayumi Kimura                                        Sorocaba SP
# Gabriela Iannini Caruso                                   São Paulo SP
# Larissa Miras Floriano                                    São Paulo SP
# Mayra Peter da Rocha Loures                                Curitiba PR
# Giovanna Sardella Cabral                                  São Paulo SP
# Sabrina Machado Bezerra                                   São Paulo SP
# Elisa Malzoni                                                 Matão SP
# ...                                                                ...
# Fernanda Parodi                                           São Paulo SP
# Lidia Guimarães Gusmão                                 Paraisópolis MG
# Mariane Martins                                       Guaratinguetá SP
# Giulia Steck                                               Louveira SP
# Carla Irrazabal                                  São Jsé dos Campos SP
# Gabriela Santos Silva                                       Diadema SP
# Fernanda Ribeiro                                          São Paulo SP
# Vanessa Freitas de Souza                                  São Paulo SP
# Esteffany Menezes Ferreira                                  Vitória ES
# Letícia Paraíso                                           São Paulo SP
# Carolina Gali Barroso                                     São Paulo SP
# Veronica G Souza                                          São Paulo SP
# Giovanna carvalho gazzillo                                São Paulo SP
# Luisa Boccardo Burini                                      Campinas SP
# Karen Cerveira Alves                                      São Paulo SP
# Lorenza De Maria Sotto Teixeira                           São Pualo SP
# Marina Cerqueira                                           Dracena  SP
# Daniela Souza de Oliveira                                  Contagem MG
# Thalita Argila Soares                                     São Paulo SP
# Nathalya Aline dos Santos Rodrigues da Silva             São Paulos SP
# Nathália de Paula Machado                                 São Paulo SP
# Laís Alves Saraiva                                        São Paulo SP
# Isabella Tolim                                            São Paulo SP
# Gustavo urenha toscano                                        Cotia SP
# Gabriela Gonçalves                                        São Paulo SP
# Lorenza De Maria Sotto Teixeira                           São Paulo SP
# Sarah Fernandes de Souza                                Santo André SP
# Amanda Vaitiman Damaceno                      São José do Rio Preto SP
# Mickaela Ester Barros Barrero                             São Paulo SP
# Barbara Alves De Melo                                     São Paulo SP
#
#                                                      TIPO_EM  \
# NOME
# Vitória de Almeida Oliveira                   Escola Privada
# manuela castilla                              Escola Privada
# Mariana Sophia Abrantes                       Escola Privada
# Maria Clara Luques                            Escola Privada
# Beatriz Alexandre                             Escola Privada
# Beatriz Mie                                   Escola Privada
# Roberta Thome                                 Escola Privada
# Rachel Maria                                  Escola Privada
# Luiza Rodrigues silveira                      Escola Privada
# Vitoria Helena de Mattos Camilo               Escola Privada
# Milena Maluli                                 Escola Pública
# Giulia Braga Passarelli                       Escola Privada
# Emanuelle Silva Moço                          Escola Pública
# Carla Kim Gaieski                             Escola Privada
# Giovana Cristina Rocha Lemes                  Escola Privada
# Maria Eduarda Peppes Bicalho                  Escola Privada
# Juliana Costa Pessoa                          Escola Privada
# Alessandra Blucher                            Escola Privada
# Isabela Frederico Ribeiro                     Escola Privada
# Lúcia Coelho Richardson                       Escola Privada
# Ana Beatriz Bertolucci Henriques              Escola Privada
# Daniela Bento                                 Escola Privada
# Isabella Rocha de Oliveira                    Escola Privada
# Bruna Mayumi Kimura                           Escola Privada
# Gabriela Iannini Caruso                       Escola Privada
# Larissa Miras Floriano                        Escola Privada
# Mayra Peter da Rocha Loures                   Escola Privada
# Giovanna Sardella Cabral                      Escola Privada
# Sabrina Machado Bezerra                       Escola Privada
# Elisa Malzoni                                 Escola Privada
# ...                                                      ...
# Fernanda Parodi                               Escola Privada
# Lidia Guimarães Gusmão                        Escola Privada
# Mariane Martins                               Escola Técnica
# Giulia Steck                                  Escola Privada
# Carla Irrazabal                               Escola Privada
# Gabriela Santos Silva                         Escola Pública
# Fernanda Ribeiro                              Escola Privada
# Vanessa Freitas de Souza                      Escola Técnica
# Esteffany Menezes Ferreira                    Escola Técnica
# Letícia Paraíso                               Escola Privada
# Carolina Gali Barroso                         Escola Pública
# Veronica G Souza                              Escola Privada
# Giovanna carvalho gazzillo                    Escola Privada
# Luisa Boccardo Burini                         Escola Privada
# Karen Cerveira Alves                          Escola Privada
# Lorenza De Maria Sotto Teixeira               Escola Privada
# Marina Cerqueira                              Escola Privada
# Daniela Souza de Oliveira                     Escola Técnica
# Thalita Argila Soares                         Escola Privada
# Nathalya Aline dos Santos Rodrigues da Silva  Escola Técnica
# Nathália de Paula Machado                     Escola Privada
# Laís Alves Saraiva                            Escola Pública
# Isabella Tolim                                Escola Privada
# Gustavo urenha toscano                        Escola Privada
# Gabriela Gonçalves                            Escola Pública
# Lorenza De Maria Sotto Teixeira               Escola Privada
# Sarah Fernandes de Souza                      Escola Privada
# Amanda Vaitiman Damaceno                      Escola Pública
# Mickaela Ester Barros Barrero                 Escola Privada
# Barbara Alves De Melo                         Escola Técnica
#
#                                                                                         NOME_EM  \
# NOME
# Vitória de Almeida Oliveira                                                         Coc Sapiens
# manuela castilla                                                                 Escola da vila
# Mariana Sophia Abrantes                                                 Colégio Dante Alighieri
# Maria Clara Luques                                                                  Pueri Domus
# Beatriz Alexandre                                                                  Porto Seguro
# Beatriz Mie                                                                    Colégio Harmonia
# Roberta Thome                                                                   Dante Alighieri
# Rachel Maria                                                                       Porto Seguro
# Luiza Rodrigues silveira                                                               Nacional
# Vitoria Helena de Mattos Camilo                                                        Objetivo
# Milena Maluli                                                             Colégio Santo Américo
# Giulia Braga Passarelli                                                            Bandeirantes
# Emanuelle Silva Moço                                                                       IFSP
# Carla Kim Gaieski                                                   Colégio Miguel de Cervantes
# Giovana Cristina Rocha Lemes                                                  Objetivo Sorocaba
# Maria Eduarda Peppes Bicalho                                           Colegio anglo brasileiro
# Juliana Costa Pessoa                                                   Visconde de Porto Seguro
# Alessandra Blucher                                                                 Bandeirantes
# Isabela Frederico Ribeiro                                                          Porto Seguro
# Lúcia Coelho Richardson                                                                Nota Dez
# Ana Beatriz Bertolucci Henriques                                                 Mater Amabilis
# Daniela Bento                                                                     Escola Móbile
# Isabella Rocha de Oliveira                          Colégio Marista Arquidiocesano de São Paulo
# Bruna Mayumi Kimura                                                                    Uirapuru
# Gabriela Iannini Caruso                                                              Santa Cruz
# Larissa Miras Floriano                                                         Colégio Humboldt
# Mayra Peter da Rocha Loures                                                    Colegio Positivo
# Giovanna Sardella Cabral                                                  Colegio Albert Sabin
# Sabrina Machado Bezerra                                           Escola Waldorf Rudolf Steiner
# Elisa Malzoni                                                                               COC
# ...                                                                                         ...
# Fernanda Parodi                                                                Colégio Stockler
# Lidia Guimarães Gusmão                                                    Colégio Santa Ângela
# Mariane Martins                               Colégio Técnico Industrial de Guaratinguetá UNESP
# Giulia Steck                                                  Colégio Visconde de Porto Seguro
# Carla Irrazabal                                                                           anglo
# Gabriela Santos Silva                                              E. e. Senador Filinto Müller
# Fernanda Ribeiro                                                                  Rumo Inicial
# Vanessa Freitas de Souza                                      Etec Professor Basilides de Godoy
# Esteffany Menezes Ferreira                                                                 IFES
# Letícia Paraíso                                                                        Objetivo
# Carolina Gali Barroso                                                          ETEC Lauro Gomes
# Veronica G Souza                                                                          Etapa
# Giovanna carvalho gazzillo                                                                Etapa
# Luisa Boccardo Burini                                                          Escola São Paulo
# Karen Cerveira Alves                                                                       Rumo
# Lorenza De Maria Sotto Teixeira                                               Colégio Santo Ivo
# Marina Cerqueira                                                                    Anglo - CID
# Daniela Souza de Oliveira                                                            CEFET - MG
# Thalita Argila Soares                                                       Colegio Notre Dame
# Nathalya Aline dos Santos Rodrigues da Silva                                ETEC Getúlio Vargas
# Nathália de Paula Machado                                                               Privest
# Laís Alves Saraiva                                                                 Olga Benatti
# Isabella Tolim                                                          São Francisco de Assis
# Gustavo urenha toscano                                                                 Objetivo
# Gabriela Gonçalves                                                         Etec Getúlio Vargas
# Lorenza De Maria Sotto Teixeira                                               Colégio Santo Ivo
# Sarah Fernandes de Souza                                                               Singular
# Amanda Vaitiman Damaceno                                          Etec Philadelpho Gouvea Netto
# Mickaela Ester Barros Barrero                                                           Sidarta
# Barbara Alves De Melo                                                           ETEC São Mateus
#
#                                              Algum familiar trabalha na área de engenharia?  \
# NOME
# Vitória de Almeida Oliveira                                                             Não
# manuela castilla                                                                        Sim
# Mariana Sophia Abrantes                                                                 Sim
# Maria Clara Luques                                                                      Sim
# Beatriz Alexandre                                                                       Sim
# Beatriz Mie                                                                             Sim
# Roberta Thome                                                                           Sim
# Rachel Maria                                                                            Não
# Luiza Rodrigues silveira                                                                Não
# Vitoria Helena de Mattos Camilo                                                         Sim
# Milena Maluli                                                                           Sim
# Giulia Braga Passarelli                                                                 Não
# Emanuelle Silva Moço                                                                    Sim
# Carla Kim Gaieski                                                                       Sim
# Giovana Cristina Rocha Lemes                                                            Não
# Maria Eduarda Peppes Bicalho                                                            Sim
# Juliana Costa Pessoa                                                                    Sim
# Alessandra Blucher                                                                      Sim
# Isabela Frederico Ribeiro                                                               Não
# Lúcia Coelho Richardson                                                                 Sim
# Ana Beatriz Bertolucci Henriques                                                        Não
# Daniela Bento                                                                           Não
# Isabella Rocha de Oliveira                                                              Não
# Bruna Mayumi Kimura                                                                     Não
# Gabriela Iannini Caruso                                                                 Sim
# Larissa Miras Floriano                                                                  Não
# Mayra Peter da Rocha Loures                                                             Sim
# Giovanna Sardella Cabral                                                                Sim
# Sabrina Machado Bezerra                                                                 Não
# Elisa Malzoni                                                                           Não
# ...                                                                                     ...
# Fernanda Parodi                                                                         Não
# Lidia Guimarães Gusmão                                                                  Sim
# Mariane Martins                                                                         Não
# Giulia Steck                                                                            Sim
# Carla Irrazabal                                                                         Sim
# Gabriela Santos Silva                                                                   Não
# Fernanda Ribeiro                                                                        Sim
# Vanessa Freitas de Souza                                                                Não
# Esteffany Menezes Ferreira                                                              Não
# Letícia Paraíso                                                                         Não
# Carolina Gali Barroso                                                                   Não
# Veronica G Souza                                                                        Sim
# Giovanna carvalho gazzillo                                                              Não
# Luisa Boccardo Burini                                                                   Sim
# Karen Cerveira Alves                                                                    Não
# Lorenza De Maria Sotto Teixeira                                                         Sim
# Marina Cerqueira                                                                        Não
# Daniela Souza de Oliveira                                                               Não
# Thalita Argila Soares                                                                   Não
# Nathalya Aline dos Santos Rodrigues da Silva                                            Não
# Nathália de Paula Machado                                                               Não
# Laís Alves Saraiva                                                                      Não
# Isabella Tolim                                                                          Sim
# Gustavo urenha toscano                                                                  Sim
# Gabriela Gonçalves                                                                      Não
# Lorenza De Maria Sotto Teixeira                                                         Sim
# Sarah Fernandes de Souza                                                                Não
# Amanda Vaitiman Damaceno                                                                Não
# Mickaela Ester Barros Barrero                                                           Não
# Barbara Alves De Melo                                                                   Não
#
#                                              Se SIM na pergunta anterior,  quais familiares?  \
# NOME
# Vitória de Almeida Oliveira                                                          Ninguém
# manuela castilla                                                                   Pai e tio
# Mariana Sophia Abrantes                                                           Pai e mãe
# Maria Clara Luques                                                    Pai, padrasto e irmão
# Beatriz Alexandre                                                                  Mãe e Pai
# Beatriz Mie                                                                           Primas
# Roberta Thome                                                                        Meu pai
# Rachel Maria                                                                         Ninguém
# Luiza Rodrigues silveira                                                             Ninguém
# Vitoria Helena de Mattos Camilo                                                   pai e mãe
# Milena Maluli                                                                            Pai
# Giulia Braga Passarelli                                                              Ninguém
# Emanuelle Silva Moço                                                                    Pai
# Carla Kim Gaieski                                                           Irmão, pai e tio
# Giovana Cristina Rocha Lemes                                                         Ninguém
# Maria Eduarda Peppes Bicalho                                                             Pai
# Juliana Costa Pessoa                                                                     Pai
# Alessandra Blucher                                                                 Meu pai.
# Isabela Frederico Ribeiro                                                            Ninguém
# Lúcia Coelho Richardson                                                 Dois primos e um tio
# Ana Beatriz Bertolucci Henriques                                                     Ninguém
# Daniela Bento                                                                        Ninguém
# Isabella Rocha de Oliveira                                                           Ninguém
# Bruna Mayumi Kimura                                                                  Ninguém
# Gabriela Iannini Caruso                                                    Pai, tio e primos
# Larissa Miras Floriano                                                               Ninguém
# Mayra Peter da Rocha Loures                                                              Avô
# Giovanna Sardella Cabral                                                Pais, tios e primos
# Sabrina Machado Bezerra                                                              Ninguém
# Elisa Malzoni                                                                        Ninguém
# ...                                                                                      ...
# Fernanda Parodi                                                                      Ninguém
# Lidia Guimarães Gusmão                                                                 Irmã
# Mariane Martins                                                                      Ninguém
# Giulia Steck                                                             Meu pai e meu irmão
# Carla Irrazabal                                                             mãe, pai e irmão
# Gabriela Santos Silva                                                                Ninguém
# Fernanda Ribeiro                                                                       Irmã
# Vanessa Freitas de Souza                                                             Ninguém
# Esteffany Menezes Ferreira                                                           Ninguém
# Letícia Paraíso                                                                      Ninguém
# Carolina Gali Barroso                                                                Ninguém
# Veronica G Souza                                                                        Irmã
# Giovanna carvalho gazzillo                                                           Ninguém
# Luisa Boccardo Burini                                                                    Pai
# Karen Cerveira Alves                                                                 Ninguém
# Lorenza De Maria Sotto Teixeira                                                          Pai
# Marina Cerqueira                                                                     Ninguém
# Daniela Souza de Oliveira                                                            Ninguém
# Thalita Argila Soares                                                                Ninguém
# Nathalya Aline dos Santos Rodrigues da Silva                                         Ninguém
# Nathália de Paula Machado                                                            Ninguém
# Laís Alves Saraiva                                                                   Ninguém
# Isabella Tolim                                                                           Pai
# Gustavo urenha toscano                                                        Primo e primas
# Gabriela Gonçalves                                                                   Ninguém
# Lorenza De Maria Sotto Teixeira                                                          Pai
# Sarah Fernandes de Souza                                                             Ninguém
# Amanda Vaitiman Damaceno                                                             Ninguém
# Mickaela Ester Barros Barrero                                                        Ninguém
# Barbara Alves De Melo                                                                Ninguém
#
#                                              Engenharia foi sua 1a escolha?  \
# NOME
# Vitória de Almeida Oliveira                                             Sim
# manuela castilla                                                        Não
# Mariana Sophia Abrantes                                                 Sim
# Maria Clara Luques                                                      Sim
# Beatriz Alexandre                                                       Sim
# Beatriz Mie                                                             Sim
# Roberta Thome                                                           Não
# Rachel Maria                                                            Não
# Luiza Rodrigues silveira                                                Sim
# Vitoria Helena de Mattos Camilo                                         Sim
# Milena Maluli                                                           Sim
# Giulia Braga Passarelli                                                 Sim
# Emanuelle Silva Moço                                                    Sim
# Carla Kim Gaieski                                                       Sim
# Giovana Cristina Rocha Lemes                                            Sim
# Maria Eduarda Peppes Bicalho                                            Sim
# Juliana Costa Pessoa                                                    Sim
# Alessandra Blucher                                                      Sim
# Isabela Frederico Ribeiro                                               Sim
# Lúcia Coelho Richardson                                                 Sim
# Ana Beatriz Bertolucci Henriques                                        Sim
# Daniela Bento                                                           Sim
# Isabella Rocha de Oliveira                                              Não
# Bruna Mayumi Kimura                                                     Não
# Gabriela Iannini Caruso                                                 Sim
# Larissa Miras Floriano                                                  Sim
# Mayra Peter da Rocha Loures                                             Sim
# Giovanna Sardella Cabral                                                Sim
# Sabrina Machado Bezerra                                                 Sim
# Elisa Malzoni                                                           Sim
# ...                                                                     ...
# Fernanda Parodi                                                         Sim
# Lidia Guimarães Gusmão                                                  Sim
# Mariane Martins                                                         Sim
# Giulia Steck                                                            Não
# Carla Irrazabal                                                         Sim
# Gabriela Santos Silva                                                   Sim
# Fernanda Ribeiro                                                        Sim
# Vanessa Freitas de Souza                                                Sim
# Esteffany Menezes Ferreira                                              Sim
# Letícia Paraíso                                                         Sim
# Carolina Gali Barroso                                                   Sim
# Veronica G Souza                                                        Sim
# Giovanna carvalho gazzillo                                              Não
# Luisa Boccardo Burini                                                   Sim
# Karen Cerveira Alves                                                    Sim
# Lorenza De Maria Sotto Teixeira                                         Sim
# Marina Cerqueira                                                        Sim
# Daniela Souza de Oliveira                                               Sim
# Thalita Argila Soares                                                   Sim
# Nathalya Aline dos Santos Rodrigues da Silva                            Sim
# Nathália de Paula Machado                                               Não
# Laís Alves Saraiva                                                      Sim
# Isabella Tolim                                                          Sim
# Gustavo urenha toscano                                                  Não
# Gabriela Gonçalves                                                      Sim
# Lorenza De Maria Sotto Teixeira                                         Sim
# Sarah Fernandes de Souza                                                Sim
# Amanda Vaitiman Damaceno                                                Sim
# Mickaela Ester Barros Barrero                                           Sim
# Barbara Alves De Melo                                                   Não
#
#                                                                    Por que escolheu Engenharia?  \
# NOME
# Vitória de Almeida Oliveira                                                     Gosta de Exatas
# manuela castilla                              Gosta de Exatas, Desde de criança brinca com e...
# Mariana Sophia Abrantes                       Gosta de Exatas, Desde de criança brinca com e...
# Maria Clara Luques                            Gosta de Exatas, Desde de criança brinca com e...
# Beatriz Alexandre                             Gosta de Exatas, Melhor para o mercado (Facili...
# Beatriz Mie                                   Gosta de Exatas, Melhor para o mercado (Facili...
# Roberta Thome                                                                   Gosta de Exatas
# Rachel Maria                                  Gosta de Exatas, Melhor para o mercado (Facili...
# Luiza Rodrigues silveira                                                        Gosta de Exatas
# Vitoria Helena de Mattos Camilo               Gosta de Exatas, Desde de criança brinca com e...
# Milena Maluli                                 Gosta de Exatas, Melhor para o mercado (Facili...
# Giulia Braga Passarelli                       Gosta de Exatas, Melhor para o mercado (Facili...
# Emanuelle Silva Moço                          Gosta de Exatas, Desde de criança brinca com e...
# Carla Kim Gaieski                             Gosta de Exatas, Melhor para o mercado (Facili...
# Giovana Cristina Rocha Lemes                  Gosta de Exatas, Desde de criança brinca com e...
# Maria Eduarda Peppes Bicalho                  Melhor para o mercado (Facilidade em atuar em ...
# Juliana Costa Pessoa                          Gosta de Exatas, Melhor para o mercado (Facili...
# Alessandra Blucher                            Gosta de Exatas, Desde de criança brinca com e...
# Isabela Frederico Ribeiro                     Gosta de Exatas, Desde de criança brinca com e...
# Lúcia Coelho Richardson                                                         Gosta de Exatas
# Ana Beatriz Bertolucci Henriques                       Desde de criança brinca com essas coisas
# Daniela Bento                                 Gosta de Exatas, Desde de criança brinca com e...
# Isabella Rocha de Oliveira                                    Me apaixonei pelo curso do Insper
# Bruna Mayumi Kimura                           O Insper só oferecia engenharia da computação ...
# Gabriela Iannini Caruso                       Gosta de Exatas, Melhor para o mercado (Facili...
# Larissa Miras Floriano                        Gosta de Exatas, Melhor para o mercado (Facili...
# Mayra Peter da Rocha Loures                   Gosta de Exatas, Melhor para o mercado (Facili...
# Giovanna Sardella Cabral                      Gosta de Exatas, Melhor para o mercado (Facili...
# Sabrina Machado Bezerra                                                         Gosta de Exatas
# Elisa Malzoni                                 Gosta de Exatas, Desde de criança brinca com e...
# ...                                                                                         ...
# Fernanda Parodi                               Gosta de Exatas, Melhor para o mercado (Facili...
# Lidia Guimarães Gusmão                        Gosta de Exatas, Melhor para o mercado (Facili...
# Mariane Martins                                        Desde de criança brinca com essas coisas
# Giulia Steck                                  Gosta de Exatas, Desde de criança brinca com e...
# Carla Irrazabal                                                                 Gosta de Exatas
# Gabriela Santos Silva                         Gosta de Exatas, Único curso rentável para áre...
# Fernanda Ribeiro                              Gosta de Exatas, Melhor para o mercado (Facili...
# Vanessa Freitas de Souza                      Gosta de Exatas, Desde de criança brinca com e...
# Esteffany Menezes Ferreira                                          Interesse sirgiu no tecnico
# Letícia Paraíso                               Gosta de Exatas, Melhor maneira de eu aplicar ...
# Carolina Gali Barroso                                                           Gosta de Exatas
# Veronica G Souza                              Gosta de Exatas, Melhor para o mercado (Facili...
# Giovanna carvalho gazzillo                                                      Gosta de Exatas
# Luisa Boccardo Burini                         Gosta de Exatas, Desde de criança brinca com e...
# Karen Cerveira Alves                          Gosta de Exatas, Desde de criança brinca com e...
# Lorenza De Maria Sotto Teixeira               Gosta de Exatas, Desde de criança brinca com e...
# Marina Cerqueira                                                                Gosta de Exatas
# Daniela Souza de Oliveira                     Gosta de Exatas, Desde de criança brinca com e...
# Thalita Argila Soares                         Gosta de Exatas, Desde de criança brinca com e...
# Nathalya Aline dos Santos Rodrigues da Silva  Gosta de Exatas, Desde de criança brinca com e...
# Nathália de Paula Machado                                                       Gosta de Exatas
# Laís Alves Saraiva                            Gosta de Exatas, Melhor para o mercado (Facili...
# Isabella Tolim                                Melhor para o mercado (Facilidade em atuar em ...
# Gustavo urenha toscano                                                          Gosta de Exatas
# Gabriela Gonçalves                                     Desde de criança brinca com essas coisas
# Lorenza De Maria Sotto Teixeira               Gosta de Exatas, Desde de criança brinca com e...
# Sarah Fernandes de Souza                                                        Gosta de Exatas
# Amanda Vaitiman Damaceno                      Gosta de Exatas, Melhor para o mercado (Facili...
# Mickaela Ester Barros Barrero                                                   Gosta de Exatas
# Barbara Alves De Melo                         Gosta de Exatas, Melhor para o mercado (Facili...
#
#                                              Sua atual faculdade foi sua 1a opção?  \
# NOME
# ...
# Luisa Boccardo Burini                                                        R$ 5000 - R$ 10000
# Karen Cerveira Alves                                                         R$ 5000 - R$ 10000
# Lorenza De Maria Sotto Teixeira                                              R$ 5000 - R$ 10000
# Marina Cerqueira                                                             R$ 5000 - R$ 10000
# Daniela Souza de Oliveira                                                    R$ 5000 - R$ 10000
# Thalita Argila Soares                                                        R$ 5000 - R$ 10000
# Nathalya Aline dos Santos Rodrigues da Silva                                 R$ 5000 - R$ 10000
# Nathália de Paula Machado                                                    R$ 5000 - R$ 10000
# Laís Alves Saraiva                                                          R$ 10000 - R$ 15000
# Isabella Tolim                                                               R$ 5000 - R$ 10000
# Gustavo urenha toscano                                                      R$ 10000 - R$ 15000
# Gabriela Gonçalves                                                           R$ 5000 - R$ 10000
# Lorenza De Maria Sotto Teixeira                                              R$ 5000 - R$ 10000
# Sarah Fernandes de Souza                                                     R$ 5000 - R$ 10000
# Amanda Vaitiman Damaceno                                                     R$ 5000 - R$ 10000
# Mickaela Ester Barros Barrero                                                R$ 5000 - R$ 10000
# Barbara Alves De Melo                                                        R$ 5000 - R$ 10000
#
#                                              Com quantos anos você espera se aposentar?  \
# NOME
# Vitória de Almeida Oliveira                                          Entre 62 a 65 anos
# manuela castilla                                                     Entre 62 a 65 anos
# Mariana Sophia Abrantes                                              Entre 62 a 65 anos
# Maria Clara Luques                                                   Entre 65 a 70 anos
# Beatriz Alexandre                                                    Entre 65 a 70 anos
# Beatriz Mie                                                          Entre 65 a 70 anos
# Roberta Thome                                                        Entre 62 a 65 anos
# Rachel Maria                                                         Entre 65 a 70 anos
# Luiza Rodrigues silveira                                             Entre 65 a 70 anos
# Vitoria Helena de Mattos Camilo                                      Entre 62 a 65 anos
# Milena Maluli                                                        Entre 65 a 70 anos
# Giulia Braga Passarelli                                              Entre 65 a 70 anos
# Emanuelle Silva Moço                                                 Entre 62 a 65 anos
# Carla Kim Gaieski                                                    Entre 65 a 70 anos
# Giovana Cristina Rocha Lemes                                         Entre 65 a 70 anos
# Maria Eduarda Peppes Bicalho                                           Acima de 70 anos
# Juliana Costa Pessoa                                                 Entre 62 a 65 anos
# Alessandra Blucher                                                   Entre 65 a 70 anos
# Isabela Frederico Ribeiro                                            Entre 65 a 70 anos
# Lúcia Coelho Richardson                                              Entre 65 a 70 anos
# Ana Beatriz Bertolucci Henriques                                       Acima de 70 anos
# Daniela Bento                                                        Entre 65 a 70 anos
# Isabella Rocha de Oliveira                                           Entre 65 a 70 anos
# Bruna Mayumi Kimura                                                  Entre 65 a 70 anos
# Gabriela Iannini Caruso                                                Acima de 70 anos
# Larissa Miras Floriano                                                 Acima de 70 anos
# Mayra Peter da Rocha Loures                                          Entre 65 a 70 anos
# Giovanna Sardella Cabral                                             Entre 65 a 70 anos
# Sabrina Machado Bezerra                                              Entre 65 a 70 anos
# Elisa Malzoni                                                        Entre 62 a 65 anos
# ...                                                                                 ...
# Fernanda Parodi                                                        Acima de 70 anos
# Lidia Guimarães Gusmão                                               Entre 65 a 70 anos
# Mariane Martins                                                      Entre 62 a 65 anos
# Giulia Steck                                                         Entre 65 a 70 anos
# Carla Irrazabal                                                      Entre 65 a 70 anos
# Gabriela Santos Silva                                                Entre 62 a 65 anos
# Fernanda Ribeiro                                                     Entre 65 a 70 anos
# Vanessa Freitas de Souza                                             Entre 62 a 65 anos
# Esteffany Menezes Ferreira                                           Entre 62 a 65 anos
# Letícia Paraíso                                                      Entre 65 a 70 anos
# Carolina Gali Barroso                                                  Acima de 70 anos
# Veronica G Souza                                                     Entre 62 a 65 anos
# Giovanna carvalho gazzillo                                           Entre 65 a 70 anos
# Luisa Boccardo Burini                                                  Acima de 70 anos
# Karen Cerveira Alves                                                 Entre 62 a 65 anos
# Lorenza De Maria Sotto Teixeira                                      Entre 65 a 70 anos
# Marina Cerqueira                                                     Entre 62 a 65 anos
# Daniela Souza de Oliveira                                            Entre 62 a 65 anos
# Thalita Argila Soares                                                Entre 62 a 65 anos
# Nathalya Aline dos Santos Rodrigues da Silva                         Entre 62 a 65 anos
# Nathália de Paula Machado                                            Entre 62 a 65 anos
# Laís Alves Saraiva                                                   Entre 62 a 65 anos
# Isabella Tolim                                                       Entre 65 a 70 anos
# Gustavo urenha toscano                                               Entre 62 a 65 anos
# Gabriela Gonçalves                                                   Entre 62 a 65 anos
# Lorenza De Maria Sotto Teixeira                                      Entre 65 a 70 anos
# Sarah Fernandes de Souza                                             Entre 62 a 65 anos
# Amanda Vaitiman Damaceno                                             Entre 62 a 65 anos
# Mickaela Ester Barros Barrero                                        Entre 62 a 65 anos
# Barbara Alves De Melo                                                Entre 62 a 65 anos
#
#                                              Você pretende ter filhos?  \
# NOME
# Vitória de Almeida Oliveira                                        Não
# manuela castilla                                                   Sim
# Mariana Sophia Abrantes                                            Sim
# Maria Clara Luques                                                 Não
# Beatriz Alexandre                                                  Sim
# Beatriz Mie                                                        Sim
# Roberta Thome                                                      Sim
# Rachel Maria                                                       Não
# Luiza Rodrigues silveira                                           Sim
# Vitoria Helena de Mattos Camilo                                    Sim
# Milena Maluli                                                      Sim
# Giulia Braga Passarelli                                            Sim
# Emanuelle Silva Moço                                               Sim
# Carla Kim Gaieski                                                  Sim
# Giovana Cristina Rocha Lemes                                       Sim
# Maria Eduarda Peppes Bicalho                                       Sim
# Juliana Costa Pessoa                                               Sim
# Alessandra Blucher                                                 Sim
# Isabela Frederico Ribeiro                                          Sim
# Lúcia Coelho Richardson                                            Sim
# Ana Beatriz Bertolucci Henriques                                   Não
# Daniela Bento                                                      Sim
# Isabella Rocha de Oliveira                                         Sim
# Bruna Mayumi Kimura                                                Sim
# Gabriela Iannini Caruso                                            Sim
# Larissa Miras Floriano                                             Não
# Mayra Peter da Rocha Loures                                        Sim
# Giovanna Sardella Cabral                                           Sim
# Sabrina Machado Bezerra                                            Sim
# Elisa Malzoni                                                      Sim
# ...                                                                ...
# Fernanda Parodi                                                    Não
# Lidia Guimarães Gusmão                                             Não
# Mariane Martins                                                    Sim
# Giulia Steck                                                       Não
# Carla Irrazabal                                                    Não
# Gabriela Santos Silva                                              Sim
# Fernanda Ribeiro                                                   Não
# Vanessa Freitas de Souza                                           Não
# Esteffany Menezes Ferreira                                         Não
# Letícia Paraíso                                                    Sim
# Carolina Gali Barroso                                              Sim
# Veronica G Souza                                                   Sim
# Giovanna carvalho gazzillo                                         Sim
# Luisa Boccardo Burini                                              Não
# Karen Cerveira Alves                                               Sim
# Lorenza De Maria Sotto Teixeira                                    Sim
# Marina Cerqueira                                                   Sim
# Daniela Souza de Oliveira                                          Não
# Thalita Argila Soares                                              Não
# Nathalya Aline dos Santos Rodrigues da Silva                       Não
# Nathália de Paula Machado                                          Sim
# Laís Alves Saraiva                                                 Sim
# Isabella Tolim                                                     Sim
# Gustavo urenha toscano                                             Sim
# Gabriela Gonçalves                                                 Sim
# Lorenza De Maria Sotto Teixeira                                    Sim
# Sarah Fernandes de Souza                                           Sim
# Amanda Vaitiman Damaceno                                           Sim
# Mickaela Ester Barros Barrero                                      Não
# Barbara Alves De Melo                                              Não
#
#                                              Fez Insper?
# NOME
# Vitória de Almeida Oliveira                          Sim
# manuela castilla                                     Sim
# Mariana Sophia Abrantes                              Sim
# Maria Clara Luques                                   Sim
# Beatriz Alexandre                                    Sim
# Beatriz Mie                                          Sim
# Roberta Thome                                        Sim
# Rachel Maria                                         Sim
# Luiza Rodrigues silveira                             Sim
# Vitoria Helena de Mattos Camilo                      Sim
# Milena Maluli                                        Sim
# Giulia Braga Passarelli                              Sim
# Emanuelle Silva Moço                                 Sim
# Carla Kim Gaieski                                    Sim
# Giovana Cristina Rocha Lemes                         Sim
# Maria Eduarda Peppes Bicalho                         Sim
# Juliana Costa Pessoa                                 Sim
# Alessandra Blucher                                   Sim
# Isabela Frederico Ribeiro                            Sim
# Lúcia Coelho Richardson                              Sim
# Ana Beatriz Bertolucci Henriques                     Sim
# Daniela Bento                                        Sim
# Isabella Rocha de Oliveira                           Sim
# Bruna Mayumi Kimura                                  Sim
# Gabriela Iannini Caruso                              Sim
# Larissa Miras Floriano                               Sim
# Mayra Peter da Rocha Loures                          Sim
# Giovanna Sardella Cabral                             Sim
# Sabrina Machado Bezerra                              Sim
# Elisa Malzoni                                        Sim
# ...                                                  ...
# Fernanda Parodi                                      Não
# Lidia Guimarães Gusmão                               Não
# Mariane Martins                                      Não
# Giulia Steck                                         Não
# Carla Irrazabal                                      Não
# Gabriela Santos Silva                                Não
# Fernanda Ribeiro                                     Não
# Vanessa Freitas de Souza                             Não
# Esteffany Menezes Ferreira                           Não
# Letícia Paraíso                                      Não
# Carolina Gali Barroso                                Não
# Veronica G Souza                                     Não
# Giovanna carvalho gazzillo                           Não
# Luisa Boccardo Burini                                Não
# Karen Cerveira Alves                                 Não
# Lorenza De Maria Sotto Teixeira                      Não
# Marina Cerqueira                                     Não
# Daniela Souza de Oliveira                            Não
# Thalita Argila Soares                                Não
# Nathalya Aline dos Santos Rodrigues da Silva         Não
# Nathália de Paula Machado                            Não
# Laís Alves Saraiva                                   Não
# Isabella Tolim                                       Não
# Gustavo urenha toscano                               Não
# Gabriela Gonçalves                                   Não
# Lorenza De Maria Sotto Teixeira                      Não
# Sarah Fernandes de Souza                             Não
# Amanda Vaitiman Damaceno                             Não
# Mickaela Ester Barros Barrero                        Não
# Barbara Alves De Melo                                Não
#
# [120 rows x 19 columns]

# %%
sp = len(eng[eng['ESTADO/CID'].str.contains('SP|Sp', case=False)])
sc = len(eng[eng['ESTADO/CID'].str.contains('SC', case=False)])
mg =len(eng[eng['ESTADO/CID'].str.contains('MG', case=False)])
to = len(eng[eng['ESTADO/CID'].str.contains('TO', case=False)])
ba = len(eng[eng['ESTADO/CID'].str.contains('BA', case=False)])
rj = len(eng[eng['ESTADO/CID'].str.contains('RJ', case=False)])
pr = len(eng[eng['ESTADO/CID'].str.contains('PR', case=False)])
ms = len(eng[eng['ESTADO/CID'].str.contains('MS', case=False)])
es = len(eng[eng['ESTADO/CID'].str.contains('ES', case=False)])
go = len(eng[eng['ESTADO/CID'].str.contains('GO', case=False)])

# %%
torta_es = []
torta_es.append(sp)
torta_es.append(sc)
torta_es.append(mg)
torta_es.append(to)
torta_es.append(ba)
torta_es.append(rj)
torta_es.append(pr)
torta_es.append(ms)
torta_es.append(es)
torta_es.append(go)

nomes_es =[]
nomes_es.append("SP")
nomes_es.append("SC")
nomes_es.append("MG")
nomes_es.append("TO")
nomes_es.append("BA")
nomes_es.append("RJ")
nomes_es.append("PR")
nomes_es.append("MS")
nomes_es.append("ES")
nomes_es.append("GO")

tortas_es = pd.DataFrame()
tortas_es["quem"]= nomes_es
tortas_es["estado"] = torta_es

tortas_es.idx = tortas_es.set_index("quem")
tortas_es.idx

print(tortas_es)
# Out:
#   quem  estado
# 0   SP     104
# 1   SC       3
# 2   MG       6
# 3   TO       5
# 4   BA       9
# 5   RJ       2
# 6   PR       2
# 7   MS       1
# 8   ES       3
# 9   GO       2
# C:\Users\Beatriz\Anaconda3\lib\site-packages\ipykernel_launcher.py:29: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access

# %%
estados = tortas_es.idx["estado"]
estados.plot(kind="pie", autopct="%.2f", legend=False)
plt.title("de onde cada uma venho")
# Out:
# Text(0.5,1,'de onde cada uma venho')

# %%
eng["ESTADO/CID"].value_counts()
# Out:
# São Paulo SP                61
# Sorocaba SP                  3
# Campinas SP                  3
# Guarulhos SP                 2
# Rio de Janeiro RJ            2
# Santos SP                    2
# Goiania GO                   1
# São Jsé dos Campos SP        1
# São Pauo SP                  1
# ão Pualo SP                  1
# Guararema SP                 1
# Cotia SP                     1
# São Pualo SP                 1
# Indaiatuba SP                1
# Paraisópolis MG              1
# Mauá SP                      1
# Guaratinguetá SP             1
# Caieiras SP                  1
# Vitória ES                   1
# Araçatuba SP                 1
# Curitiba PR                  1
# São Pailo SP                 1
# Contagem MG                  1
# SC                           1
# Cacapava Sp                  1
# Uberlândia MG                1
# Governador Valadares MG      1
# São José do Rio Preto SP     1
# São José do Rio Pardo SP     1
# São Roque SP                 1
# São Bernardo do Campo Sp     1
# Mogi das Cruzes SP           1
# Itapema SC                   1
# São Bernardo SP              1
# Barueri SP                   1
# Louveira SP                  1
# São Paulo sP                 1
# Lins SP                      1
# Porto Alegre RS              1
# São pAulo SP                 1
# SBC SP                       1
# Dracena  SP                  1
# Campo Grande MS              1
# Santo André SP               1
# Itanhandu MG                 1
# São Paulos SP                1
# Diadema SP                   1
# São Bernardo do Campo SP     1
# Matão SP                     1
# Salvador BA                  1
# Taubaté SP                   1
# Belo Horizonte MG            1
# Osasco SP                    1
# Name: ESTADO/CID, dtype: int64

# %%
eng.TIPO_EM.value_counts().plot.bar()
plt.title("Tipo de EM");

# %%
eng["Algum familiar trabalha na área de engenharia?"].value_counts().plot.bar()
plt.title("se tem familiares na engenharia");

# %%
eng["TIPO_ENG"].value_counts().plot.bar()
plt.title("Qual tipo de engenharia");

# %% [markdown]
# Limpeza da Coluna de quais familiares na engenharia

# %%
mae = 0
maeL =[]

avos = 0
avosL =[]

pai = 0
paiL =[]

tio = 0
tioL=[]

irmaos =0
irmaosL =[]

ninguem = 0
ninguemL =[]

padrasto = 0
padrastoL=[]

primos = 0
primosL=[]

for k in eng['Se SIM na pergunta anterior,  quais familiares?']:
    split_v = k.split(",")
    for i in split_v:
        split_e = i.split(" e")
    
    for k in split_e:
        if k == "pai" or k =="Pai" or k == "Meu pai" or k =="pai e mãe ":
            pai+=1
            paiL.append("pai")
        elif k == " mãe " or k == "Mãe" or k == "pai e mãe ":
            mae+=1
            maeL.append("mae")
        elif k =="irmã " or k ==" meu irmão" or k ==" irmão" :
            irmaos+=1
            irmaosL.append("irmao")
        elif k ==" tio." or k ==" tios" or k =="Tios" or k ==" tio":
            tio+=1
            tioL.append("tio")
        elif "padrasto" in k.lower():
            padrasto+=1
            padrastoL.append("padrasto")
        elif "ninguém" in k.lower():
            ninguem+=1
            ninguemL.append("ninguem")
        elif "avô" in k.lower() or k==" avô":
            avos+=1
            avosL.append("avos")
        elif k ==" primos" or k =='Primo' or k==' primas' or k==" primo" or k==' primos ' or k=="Dois primos":
            primos +=1
            primosL.append("primos")

# %%
familia =[]
familia.append(maeL)
familia.append(paiL)
familia.append(irmaosL)
familia.append(tioL)
familia.append(padrastoL)
familia.append(ninguemL)
familia.append(avosL)
familia.append(primosL)
plt.hist(familia);
plt.title('Familiares na Engenharia')
# Out:
# Text(0.5,1,'Familiares na Engenharia')

# %%
eng["Fez Insper?"].value_counts().plot.bar()
plt.title("Estuda no Insper")
# Out:
# Text(0.5,1,'Estuda no Insper')

# %% [markdown]
# #  2a Análise: Faz Engenharia ou Adm/Eco no Insper?

# %% [markdown]
# # PRIMEIRO SHEET: meninas na engenharia Insper

# %%
# leitura do excel
eng_insper_2 = pd.read_excel('PESQUISA.xlsx', sheet_name = 0)

# %%
#renomeando colunas:
eng_insper_2 = eng_insper_2.rename(columns={"Qual seu nome completo?": "NOME", "Qual semestre?": "SEMESTRE", "Idade": "IDADE", "Qual engenharia?": "Curso", "De onde você veio (cidade/estado)?": "ESTADO/CID", "Frequentou o Ensino Médio...":"TIPO_EM", "Qual o nome do seu colégio?": "NOME_EM",  'Algum familiar trabalha na área de engenharia?':'Familiar na área?',  'Se SIM na pergunta anterior,  quais familiares?':'Quais familiares?', 'Engenharia foi sua 1a escolha?':'Seu curso foi sua 1a escolha?','Por que escolheu Engenharia?':'Por que escolheu este curso ?'})

#limpeza e modificações
semestre=[]

for k in eng_insper_2.SEMESTRE:
    if k == "2º Semestre":
        semestre.append(2)
    elif k == "3º Semestre":
        semestre.append(3)
    elif k == "4º Semstre":
        semestre.append(4)
    elif k =="5º Semestre":
        semestre.append(5)
    elif k =="6º semestre":
        semestre.append(6)
    elif k == "7º Semestre":
        semestre.append(7)
    else:
         semestre.append(8)
            
eng_insper_2.SEMESTRE = semestre

eng_insper_2['Se "Não", qual?'] = eng_insper_2['Se "Não", qual?'].fillna('Insper')

eng_insper_2['Faz Engenharia?']= '1'

eng_insper_2['Quais familiares?'] = eng_insper_2['Quais familiares?'].fillna('Ninguém')

# %%
eng_insper_2_idx=eng_insper_2.set_index('NOME')

# %% [markdown]
# ## QUARTO SHEET: adm/econo insper

# %% [markdown]
# Lendo arquivo Excel

# %%
insper = pd.read_excel('PESQUISA.xlsx', sheet_name = 3)

# %%
insper = insper.drop('Qual é a distância da sua casa para a faculdade', 1)

# %% [markdown]
# Limpar o DataFrame e Renomear algumas colunas

# %%
insper['Se "Não", qual?'] = insper['Se "Não", qual?'].fillna('Insper')
insper = insper.rename(columns={"Qual seu nome completo?": "NOME", "Qual semestre?": "SEMESTRE", "Idade": "IDADE", "Qual curso?": "Curso", "De onde você veio (cidade/estado)?": "ESTADO/CID", "Frequentou o Ensino Médio...":"TIPO_EM", "Qual o nome do seu colégio?": "NOME_EM", 'Algum familiar trabalha na área de adm e/ou econo?': 'Familiar na área?', 'Se SIM na pergunta anterior, quais familiares?':'Quais Familiares?', 'Adm e/ou Econo foi sua primeira escolha?':'Seu curso foi sua 1a escolha?','Por que escolheu Administração/ Economia?': 'Por que escolheu este curso?'})
semestre=[]

for k in insper.SEMESTRE:
    if k == "2º Semestre":
        semestre.append(2)
    elif k == "3º Semestre":
        semestre.append(3)
    elif k == "4º Semstre":
        semestre.append(4)
    elif k =="5º Semestre":
        semestre.append(5)
    elif k =="6º semestre":
        semestre.append(6)
    elif k == "7º Semestre":
        semestre.append(7)
    else:
         semestre.append(8)
            
insper.SEMESTRE = semestre

# %%
insper_idx=insper.set_index('NOME')

# %%
#insper_idx.columns.tolist()

# %%
insper_idx['Faz Engenharia?']='0'

# %% [markdown]
# ##### Juntando os DataFrames

# %%
#Conferir o número de colunas em cada DataFrame
print(len(eng_insper_2_idx.columns.tolist()))
print(len(insper_idx.columns.tolist()))
# Out:
# 19
# 21

# %%
Insper=pd.concat([eng_insper_2, insper_idx])
Insper.head(1)
# Out:
# C:\Users\Beatriz\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=True'.
#
# To retain the current behavior and silence the warning, pass sort=False
#
#   """Entry point for launching an IPython kernel.
#   Algum familiar na engenharia? Com quantos anos você espera se aposentar?  \
# 0                           NaN                         Entre 62 a 65 anos
#
#   Como descobriu o Insper?                   Curso ESTADO/CID  \
# 0               Por amigos  Engenharia Mecatrônica  Osasco SP
#
#   Familiar na área? Faz Engenharia?               IDADE  \
# 0               Não               1  Entre 19 a 21 anos
#
#   Insper foi sua 1a opcao?                         NOME  \
# 0                      Sim  Vitória de Almeida Oliveira
#
#              ...             \
# 0            ...
#
#   Quanto você espera ganhar no seu início de sua carreira? SEMESTRE  \
# 0                                R$ 15000 - R$ 20000              2
#
#   Se "Não", qual? Se "Sim" na pergunta anterior, quais familiares?  \
# 0          Insper                                              NaN
#
#   Se SIM na pergunta anterior,  quais familiares?  \
# 0                                             NaN
#
#   Seu curso foi sua 1a escolha?         TIPO_EM  \
# 0                           Sim  Escola Privada
#
#   Ter poucas meninas na engenharia te desmotiva a ingressar na engenharia?  \
# 0                                                Não
#
#   Ter poucas meninas no Insper te desmotiva a ingressar na instituição?  \
# 0                                                NaN
#
#   Você pretende ter filhos?
# 0                       Não
#
# [1 rows x 25 columns]

# %% [markdown]
# ###  Análise explorátoria 2.0

# %%
Insper["Familiar na área?"].value_counts().plot.bar()
plt.title("se tem familiares na área")
# Out:
# Text(0.5,1,'se tem familiares na área')

# %%
Insper['Curso'].value_counts().plot.bar()
plt.title("Qual tipo de curso?")
# Out:
# Text(0.5,1,'Qual tipo de curso?')

# %%
pai = len(eng[eng['Se SIM na pergunta anterior,  quais familiares?'].str.contains('Pai', case=False)])
print(pai)
# Out:
# 32

# %%
tio = len((eng[eng['Se SIM na pergunta anterior,  quais familiares?'].str.contains('tios', case=False)]))
print((tio))
# Out:
# 7

# %%
mae = len(eng[eng['Se SIM na pergunta anterior,  quais familiares?'].str.contains('mãe|mae', case=False)])
print(mae)
# Out:
# 8

# %%
irmaos = len(eng[eng['Se SIM na pergunta anterior,  quais familiares?'].str.contains('irmã|irmão|irma|irmao', case=False)])
print(irmaos)
# Out:
# 12

# %%
padrasto = len(eng[eng['Se SIM na pergunta anterior,  quais familiares?'].str.contains('padrasto', case=False)])
print(padrasto)
# Out:
# 2

# %%
ninguem = len(eng[eng['Se SIM na pergunta anterior,  quais familiares?'].str.contains('ninguém', case=False)])
print(ninguem)
# Out:
# 69

# %%
avos = len(eng[eng['Se SIM na pergunta anterior,  quais familiares?'].str.contains('avô|avo', case=False)])
print(avos)
# Out:
# 6

# %%
primos = len(eng[eng['Se SIM na pergunta anterior,  quais familiares?'].str.contains('primos|prima|primo', case=False)])
print(primos)
# Out:
# 8

# %%
soma = primos+ avos+ ninguem + padrasto+ irmaos+ mae+ tio+pai
soma
# Out:
# 144

# %%
print ("a probabilidade de ter uma mãe que trabalha na engenharia é  {:.2f}%".format((mae/soma)*100))
print ("a probabilidade de ter um pai que trabalha na engenharia é {:.2f}%".format((pai/soma)*100))
print ("a probabilidade de ter um tio que trabalha na engenharia é {:.2f}%".format((tio/soma)*100))
print ("a probabilidade de ter um irmão que trabalha na engenharia é {:.2f}%".format((irmaos/soma)*100))
print ("a probabilidade de ter um padrasto que trabalha na engenharia é {:.2f}%".format((padrasto/soma)*100))
print ("a probabilidade de ter um ninguém que trabalha na engenharia é {:.2f}%".format((ninguem/soma)*100))
print ("a probabilidade de ter um avô ou uma avó que trabalha na engenharia é {:.2f}%".format((avos/soma)*100))
print ("a probabilidade de ter um primo ou uma prima que trabalha na engenharia é {:.2f}%".format((primos/soma)*100))
# Out:
# a probabilidade de ter uma mãe que trabalha na engenharia é  5.56%
# a probabilidade de ter um pai que trabalha na engenharia é 22.22%
# a probabilidade de ter um tio que trabalha na engenharia é 4.86%
# a probabilidade de ter um irmão que trabalha na engenharia é 8.33%
# a probabilidade de ter um padrasto que trabalha na engenharia é 1.39%
# a probabilidade de ter um ninguém que trabalha na engenharia é 47.92%
# a probabilidade de ter um avô ou uma avó que trabalha na engenharia é 4.17%
# a probabilidade de ter um primo ou uma prima que trabalha na engenharia é 5.56%

# %%
pie = []
pie.append(mae)
pie.append(pai)
pie.append(tio)
pie.append(irmaos)
pie.append(padrasto)
pie.append(ninguem)
pie.append(avos)
pie.append(primos)

nomes =[]
nomes.append("mae")
nomes.append("pai")
nomes.append("tio")
nomes.append("irmaos")
nomes.append("padrasto")
nomes.append("ninguem")
nomes.append("avos")
nomes.append("primos")

pies = pd.DataFrame()
pies["quem"]= nomes
pies["porcentagem de familia"] = pie

pies_idx = pies.set_index("quem")
pies_idx
# Out:
#           porcentagem de familia
# quem
# mae                            8
# pai                           32
# tio                            7
# irmaos                        12
# padrasto                       2
# ninguem                       69
# avos                           6
# primos                         8

# %%
adim = pies_idx["porcentagem de familia"]
adim.plot(kind="pie", autopct="%.2f", legend=False)
plt.title("porcentagem da familia em engenharia")
# Out:
# Text(0.5,1,'porcentagem da familia em engenharia')

# %% [markdown]
# ## PRIMEIRA REGRESSÃO

# %%
minas = pd.read_excel('PESQUISA.xlsx', sheet_name = 4)

# %%
minas_idx = minas.set_index("ENGENHARIAS")
minas_idx["_2019"] = 0
minas_idx
# Out:
#              _2015  _2016  _2017  _2018  _2019
# ENGENHARIAS
# mecatrônica      2      1      8      6      0
# computação       2      5      4      7      0
# mecânica         4      1      3      4      0

# %%
pie2015 = minas_idx["_2015"]
pie2015.plot(kind="pie", autopct="%.2f", legend=False);
plt.title("porcentagem de meninas na engenhariem 2015");

# %%
pie2016 = minas_idx["_2016"]
pie2016.plot(kind="pie", autopct="%.2f", legend=False)
plt.title("porcentagem de meninas na engenhariem 2016");

# %%
pie2017 = minas_idx["_2017"]
pie2017.plot(kind="pie", autopct="%.2f", legend=False)
plt.title("porcentagem de meninas na engenhariem 2017");

# %%
pie2018 = minas_idx["_2018"]
pie2018.plot(kind="pie", autopct="%.2f", legend=False)
plt.title("porcentagem de meninas na engenhariem 2018");

# %%
def regress(X, Y):
    X_cp = sm.add_constant(X)
    model = sm.OLS(Y, X_cp)
    results= model.fit()
    return results

# %%
quanti = minas_idx[["_2015", "_2016","_2017"]]
quanti_x = quanti.copy()
reg = regress(quanti_x, minas_idx["_2018"])
reg.summary()
# Out:
# C:\Users\Beatriz\Anaconda3\lib\site-packages\statsmodels\stats\stattools.py:72: ValueWarning: omni_normtest is not valid with less than 8 observations; 3 samples were given.
#   "samples were given." % int(n), ValueWarning)
# C:\Users\Beatriz\Anaconda3\lib\site-packages\statsmodels\regression\linear_model.py:1549: RuntimeWarning: divide by zero encountered in true_divide
#   return 1 - (np.divide(self.nobs - self.k_constant, self.df_resid)
# C:\Users\Beatriz\Anaconda3\lib\site-packages\statsmodels\regression\linear_model.py:1550: RuntimeWarning: invalid value encountered in double_scalars
#   * (1 - self.rsquared))
# C:\Users\Beatriz\Anaconda3\lib\site-packages\statsmodels\regression\linear_model.py:1558: RuntimeWarning: divide by zero encountered in double_scalars
#   return self.ssr/self.df_resid
# C:\Users\Beatriz\Anaconda3\lib\site-packages\statsmodels\regression\linear_model.py:1510: RuntimeWarning: divide by zero encountered in double_scalars
#   return np.dot(wresid, wresid) / self.df_resid
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  _2018   R-squared:                       1.000
# Model:                            OLS   Adj. R-squared:                    nan
# Method:                 Least Squares   F-statistic:                     0.000
# Date:                Thu, 22 Nov 2018   Prob (F-statistic):                nan
# Time:                        07:51:29   Log-Likelihood:                 96.927
# No. Observations:                   3   AIC:                            -187.9
# Df Residuals:                       0   BIC:                            -190.6
# Df Model:                           2
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.1588        inf          0        nan         nan         nan
# _2015          0.3556        inf          0        nan         nan         nan
# _2016          0.7922        inf          0        nan         nan         nan
# _2017          0.5422        inf          0        nan         nan         nan
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   1.623
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                0.281
# Skew:                           0.000   Prob(JB):                        0.869
# Kurtosis:                       1.500   Cond. No.                         4.01
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The input rank is higher than the number of observations.
# """

# %%
Insper_mist=Insper.sample(66)

# %%
Insper_mist.shape
# Out:
# (66, 25)

# %%
# Testa modelo.
y_pred = model.predict(X_test)

# Calcula acurácia.
acc = accuracy_score(y_test, y_pred)

print("Acurácia: {}".format(acc))
# Out:
# Acurácia: 0.96

# %%
teste = Insper_mist[:33]
treinamento= Insper_mist[33:]

# %%
X_train = (treinamento['Faz Engenharia?']=='1')
X_test = (teste['Faz Engenharia?']=='1')
y_train = (treinamento['Faz Engenharia?']=='1')
y_teste = (teste['Faz Engenharia?']=='1')

# %%
iris = datasets.load_iris()

# %%
X = iris.data[:, 2:4]
y = iris.target == 2
RANDOM_SEED = 42 # faz um random no DataFrame

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state= RANDOM_SEED)

# %% [markdown]
# ### Inicio Regressão Logística

# %%
x_logistica = np.linspace(-10, 10, 500)
y_logistica = 1/(1 + np.exp(-x_logistica))

plt.plot(x_logistica, y_logistica)
plt.xlabel('x')
plt.ylabel('y')
plt.title('Função Logística')
# Out:
# Text(0.5,1,'Função Logística')

# %%
model = LogisticRegression()
model.fit(X_train, y_train)
y_pred = model.predict(X_test)
print('Acurácia: {}'.format(accuracy_score(y_test, y_pred)))
# Out:
# Acurácia: 0.96

# %%
n = 20

for original, binarized in zip(teste["Faz Engenharia?"][:n], y_train[:n]):
    print('{} -> {}'.format(original, binarized))
# Out:
# 1 -> False
# 1 -> True
# 1 -> False
# 1 -> False
# 0 -> True
# 1 -> False
# 0 -> False
# 0 -> False
# 0 -> False
# 0 -> False
# 0 -> True
# 1 -> False
# 0 -> False
# 1 -> False
# 0 -> False
# 0 -> False
# 1 -> False
# 1 -> True
# 1 -> False
# 0 -> False

# %%
teste_array = treinamento["Faz Engenharia?"].values.reshape(1, -1)

# %%
from sklearn.linear_model import SGDClassifier

sgd_clf = SGDClassifier(max_iter=1, tol=None, random_state=RANDOM_SEED)  # Existe aleatoriedade dentro do SGDClassifier.
sgd_clf.fit(X_train, y_train)
# Out:
# SGDClassifier(alpha=0.0001, average=False, class_weight=None, epsilon=0.1,
#        eta0=0.0, fit_intercept=True, l1_ratio=0.15,
#        learning_rate='optimal', loss='hinge', max_iter=1, n_iter=None,
#        n_jobs=1, penalty='l2', power_t=0.5, random_state=42, shuffle=True,
#        tol=None, verbose=0, warm_start=False)

# %%
y_pred_mist = sgd_clf.predict(X_test)
print(y_pred_mist)
print('Accuracy: {}'.format(accuracy_score(y_test, y_pred_mist)))
# Out:
# [ True False  True  True  True False  True  True  True  True  True False
#  False False False  True  True  True  True  True False  True False  True
#   True  True  True  True False False False False  True False False  True
#   True False False False  True  True  True False False False  True  True
#   True  True]
# Accuracy: 0.72

# %% [markdown]
# # Bibliografia:
#
# * pd.concat:
# https://stackoverflow.com/questions/21435176/appending-two-dataframes-with-same-columns-different-order
#
# * como fazer um random no DataFrame:
# https://pt.stackoverflow.com/questions/324588/fazer-um-random-de-um-dataset-com-pandas
