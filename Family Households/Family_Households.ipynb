# %% [markdown]
# Por: Beatriz Alexandre e Manuela Castilla

# %% [markdown]
# # Pergunta:
#
# ## Há um crescimento no número de adoções?

# %%
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
import matplotlib as mpl  
import seaborn as sns
import numpy as np
import itertools
from scipy import stats
from emoji import UNICODE_EMOJI

# %%
df = pd.read_csv('family-households-with-married-couples.csv')
df
# Out:
#    realtime_end        date realtime_start  value
# 0    2018-10-30  1940-01-01     2018-10-30  26571
# 1    2018-10-30  1941-01-01     2018-10-30      .
# 2    2018-10-30  1942-01-01     2018-10-30      .
# 3    2018-10-30  1943-01-01     2018-10-30      .
# 4    2018-10-30  1944-01-01     2018-10-30      .
# 5    2018-10-30  1945-01-01     2018-10-30      .
# 6    2018-10-30  1946-01-01     2018-10-30      .
# 7    2018-10-30  1947-01-01     2018-10-30  30612
# 8    2018-10-30  1948-01-01     2018-10-30  31900
# 9    2018-10-30  1949-01-01     2018-10-30  33257
# 10   2018-10-30  1950-01-01     2018-10-30  34075
# 11   2018-10-30  1951-01-01     2018-10-30  34391
# 12   2018-10-30  1952-01-01     2018-10-30  35164
# 13   2018-10-30  1953-01-01     2018-10-30  35577
# 14   2018-10-30  1954-01-01     2018-10-30  35926
# 15   2018-10-30  1955-01-01     2018-10-30  36251
# 16   2018-10-30  1956-01-01     2018-10-30  37047
# 17   2018-10-30  1957-01-01     2018-10-30  37718
# ...
